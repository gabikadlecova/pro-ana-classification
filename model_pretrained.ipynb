# %%
import os
os.listdir()
# Out:
# ['.env',
#  '.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'cleaned_data.csv',
#  'cleaned_data_relevant.csv',
#  'cleaned_pro-ana-data.xls',
#  'cleaned_pro-recovery-data.xls',
#  'data.csv',
#  'data.xls',
#  'EDA_cleaning.ipynb',
#  'gensim-data',
#  'invalid_words.txt',
#  'model_cleaned.ipynb',
#  'model_pretrained.ipynb',
#  'model_tuning.ipynb',
#  'pro-ana-data.xls',
#  'pro-recovery-data.xls',
#  'proanavsprorecovery.zip',
#  'tmpres.txt']

# %%
import pandas

data = pandas.read_csv('data.csv')

# %%
# filtered out
data_f = pandas.read_csv('cleaned_data_relevant.csv')
data = data[data['id'].isin(data_f['id'])]
data

#data = data_f
#cleaned_data = data[:]
# Out:
#           id  label                                               text
# 1        2_0      0                  i had a long battle with anorexia
# 2        3_0      0   those thoughts telling me that if i just lost...
# 3        4_0      0                 the trouble is that never happened
# 4        5_0      0                     there was never a magic number
# 5        6_0      0                                it was never enough
# ...      ...    ...                                                ...
# 3364  2131_1      1  the last pro ana diet comes with a twist in at...
# 3365  2132_1      1   in this diet, you can hardly eat any carbs bu...
# 3366  2133_1      1   with this diet, you will see a drastic loss i...
# 3367  2134_1      1  well, these were some of the best pro ana diet...
# 3368  2135_1      1   everyone aims to have a thin body and these d...
#
# [3140 rows x 3 columns]

# %%
data.head()
# Out:
#     id  label                                               text
# 1  2_0      0                  i had a long battle with anorexia
# 2  3_0      0   those thoughts telling me that if i just lost...
# 3  4_0      0                 the trouble is that never happened
# 4  5_0      0                     there was never a magic number
# 5  6_0      0                                it was never enough

# %%
import string
import wordninja
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

def clean_text(text: str, stem: bool = True):
    text = text.lower()   
    remove_string = 'tcb-script]'  # random string appearing in some text samples
    text = text.replace(remove_string, '')
    
    tokens = separate_words(text)
    
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    
    tokens = [word for word in tokens if word.isalpha()]

    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    
    if stem:
        porter = PorterStemmer()
        tokens = [porter.stem(word) for word in tokens]
    
    return tokens
    
def separate_words(text):
    return wordninja.split(text)
# Out:
# [nltk_data] Downloading package stopwords to /home/gabi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from functools import partial

cleaned_data = data[:]

cleaned_data['text'] = cleaned_data['text'].apply(partial(clean_text, stem=False))
cleaned_data['text'] = cleaned_data['text'].apply(lambda t: " ".join(t))
cleaned_data.head()
# Out:
#     id  label                                               text
# 1  2_0      0                               long battle anorexia
# 2  3_0      0  thoughts telling lost x amount weight would ac...
# 3  4_0      0                             trouble never happened
# 4  5_0      0                                 never magic number
# 5  6_0      0                                       never enough

# %% [markdown]
# # Model

# %%
max_seq_len = cleaned_data['text'].apply(lambda t: len(t)).max()
max_seq_len
# Out:
# 692

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(cleaned_data, test_size=0.1)
train_X, train_y = train['text'], train['label']
test_X, test_y = test['text'], test['label']

# %%
import keras
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_X)

train_X = tokenizer.texts_to_sequences(train_X)
train_X = keras.preprocessing.sequence.pad_sequences(train_X,
                                                         maxlen=max_seq_len, padding='pre')

test_X = tokenizer.texts_to_sequences(test_X)
test_X = keras.preprocessing.sequence.pad_sequences(test_X,
                                                         maxlen=max_seq_len, padding='pre')

# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# False

# %% [markdown]
# ## Load embedding

# %%
import gensim.downloader as api
path = api.load("word2vec-google-news-300", return_path=True)
print(path)
# Out:
# /home/gabi/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz

# %%
import os
from gensim.models import KeyedVectors
from gensim.downloader import base_dir


def load_data():
    path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
    model = KeyedVectors.load_word2vec_format(path, binary=True)
    return model

pretrained_emb = load_data()

# %%
import sys
sys.path.append('/home/gabi/gensim-data/word2vec-google-news-300/')

from . import load_data
pretrained_emb = load_data()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-90c19b80c7e0> in <module>
#       2 sys.path.append('/home/gabi/gensim-data/word2vec-google-news-300/')
#       3
# ----> 4 from . import load_data
#       5 pretrained_emb = load_data()
#
# ImportError: cannot import name 'load_data'

# %%
pretrained_emb

# %%
import numpy as np

embedding_dim = 300
vocab_size = len(tokenizer.word_index)

embedding_matrix = np.zeros((vocab_size + 1, embedding_dim))
for word, i in tokenizer.word_index.items():
    try:
        embedding_vector = pretrained_emb.get_vector(word)
        embedding_matrix[i] = embedding_vector
    except:
        # words not found in embedding index will be all-zeros.
        pass

# %%
from keras.layers import Embedding

w2v_embedding = Embedding(vocab_size + 1,
                          embedding_dim,
                          weights=[embedding_matrix],
                          input_length=max_seq_len,
                          trainable=False)
orig_embedding = pretrained_emb.get_keras_embedding()

# %% [markdown]
# ## Model from word2vec keras

# %%
# Keras
from tensorflow import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Embedding, LSTM
from keras import utils
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.preprocessing import LabelEncoder


def train_model(x_train, y_train, embedding,
                k_batch_size=128, k_epochs=32, k_lstm_neurons=128,
                k_hidden_layer_neurons=(128, 64, 32), verbose=1):
    
    label_encoder = LabelEncoder()
    y_train = label_encoder.fit_transform(y_train)
    num_classes = len(label_encoder.classes_)
    y_train = utils.to_categorical(y_train, num_classes)


    k_model = Sequential()
    k_model.add(embedding)
    k_model.add(LSTM(k_lstm_neurons, dropout=0.5, recurrent_dropout=0.2))
    for hidden_layer in k_hidden_layer_neurons:
        k_model.add(Dense(hidden_layer, activation='relu'))
        k_model.add(Dropout(0.2))
    if num_classes > 1:
        k_model.add(Dense(num_classes, activation='softmax'))
    else:
        k_model.add(Dense(num_classes, activation='sigmoid'))

    k_model.compile(loss='categorical_crossentropy' if num_classes > 1 else 'binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])

    # Callbacks
    early_stopping = EarlyStopping(monitor='accuracy', patience=6, verbose=0, mode='max')
    rop = ReduceLROnPlateau(monitor='accuracy', factor=0.1, patience=3, verbose=1, epsilon=1e-4, mode='max')
    callbacks = [early_stopping, rop]
    #callbacks = [rop]
    
    k_model.fit(x_train, y_train,
                batch_size=k_batch_size,
                epochs=k_epochs,
                callbacks=callbacks,
                verbose=verbose)

    return k_model

# %%
import time

def predict(k_model, tt, label_enc, threshold=.0):
        """
        Predict raw text label
        :param text: raw text
        :param threshold: cut-off threshold, if confidence il less than given value return __OTHER__ as label
        :return: {label: LABEL, confidence: CONFIDENCE, elapsed_time: TIME}
        """
        if not k_model:
            raise RuntimeError("Model not in memory, please load it train new model")
            
        start_at = time.time()
        
        # Predict
        confidences = k_model.predict(tt)[0]
        # Get mex prediction
        idx = np.argmax(confidences)
        elapsed_time = time.time() - start_at
        if float(confidences[idx]) > threshold:
            return {"label": label_encoder.classes_[idx], "confidence": float(confidences[idx]),
                    "elapsed_time": elapsed_time}
        return {"label": "__OTHER__", "confidence": float(confidences[idx]), "elapsed_time": elapsed_time}

# %%
model = train_model(train_X, train_y, w2v_embedding, k_lstm_neurons=20, k_epochs=300, k_batch_size=32)
# Out:
# /media/win_hdd/Gabi/Code/mff/ML/NN_project/.env/lib/python3.6/site-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Epoch 1/300
# 2826/2826 [==============================] - 10s 4ms/step - loss: 0.5984 - accuracy: 0.6741
# Epoch 2/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.4548 - accuracy: 0.8022
# Epoch 3/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.4170 - accuracy: 0.8199
# Epoch 4/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.4136 - accuracy: 0.8248
# Epoch 5/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3942 - accuracy: 0.8323
# Epoch 6/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3853 - accuracy: 0.8376
# Epoch 7/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3763 - accuracy: 0.8386
# Epoch 8/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3745 - accuracy: 0.8347
# Epoch 9/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3573 - accuracy: 0.8447
# Epoch 10/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3586 - accuracy: 0.8408
# Epoch 11/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3547 - accuracy: 0.8457
# Epoch 12/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3461 - accuracy: 0.8478
# Epoch 13/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3348 - accuracy: 0.8539
# Epoch 14/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3377 - accuracy: 0.8517
# Epoch 15/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3121 - accuracy: 0.8620
# Epoch 16/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.3003 - accuracy: 0.8648
# Epoch 17/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2977 - accuracy: 0.8783
# Epoch 18/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2859 - accuracy: 0.8762
# Epoch 19/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2768 - accuracy: 0.8832
# Epoch 20/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2750 - accuracy: 0.8836
# Epoch 21/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2603 - accuracy: 0.8970
# Epoch 22/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2698 - accuracy: 0.8861
# Epoch 23/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2595 - accuracy: 0.8864
# Epoch 24/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2400 - accuracy: 0.8992
# Epoch 25/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2327 - accuracy: 0.9055
# Epoch 26/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2313 - accuracy: 0.9091
# Epoch 27/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2399 - accuracy: 0.8988
# Epoch 28/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2249 - accuracy: 0.9045
# Epoch 29/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2047 - accuracy: 0.9211
# Epoch 30/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2280 - accuracy: 0.9013
# Epoch 31/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1947 - accuracy: 0.9214
# Epoch 32/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.2015 - accuracy: 0.9147
# Epoch 33/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1971 - accuracy: 0.9119
# Epoch 34/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1938 - accuracy: 0.9243
# Epoch 35/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1948 - accuracy: 0.9158
# Epoch 36/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1797 - accuracy: 0.9243
# Epoch 37/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1888 - accuracy: 0.9218
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 38/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1503 - accuracy: 0.9345
# Epoch 39/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1457 - accuracy: 0.9388
# Epoch 40/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1571 - accuracy: 0.9296
# Epoch 41/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1481 - accuracy: 0.9406
# Epoch 42/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1619 - accuracy: 0.9328
# Epoch 43/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1499 - accuracy: 0.9363
# Epoch 44/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1561 - accuracy: 0.9391
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 45/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1520 - accuracy: 0.9356
# Epoch 46/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1633 - accuracy: 0.9285
# Epoch 47/300
# 2826/2826 [==============================] - 10s 3ms/step - loss: 0.1516 - accuracy: 0.9384
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.

# %%
res = []

for text, label in zip(test_X, test_y):
    try:
        pred = predict(model, text[np.newaxis], label_encoder)
        res.append(pred)
        print(f"{pred}, orig: {label}")
    except IndexError as e:
        print(e)
        res.append(None)
# Out:
# {'label': 1, 'confidence': 0.9999911785125732, 'elapsed_time': 0.12320137023925781}, orig: 1
# {'label': 1, 'confidence': 0.9744738340377808, 'elapsed_time': 0.022378206253051758}, orig: 1
# {'label': 1, 'confidence': 0.988387405872345, 'elapsed_time': 0.017545700073242188}, orig: 1
# {'label': 1, 'confidence': 0.9946430921554565, 'elapsed_time': 0.022649049758911133}, orig: 1
# {'label': 0, 'confidence': 0.999932050704956, 'elapsed_time': 0.024684667587280273}, orig: 0
# {'label': 1, 'confidence': 0.9818726181983948, 'elapsed_time': 0.02177715301513672}, orig: 1
# {'label': 1, 'confidence': 0.9414276480674744, 'elapsed_time': 0.01757979393005371}, orig: 1
# {'label': 1, 'confidence': 0.9999692440032959, 'elapsed_time': 0.017933368682861328}, orig: 1
# {'label': 1, 'confidence': 0.9692163467407227, 'elapsed_time': 0.017621755599975586}, orig: 0
# {'label': 1, 'confidence': 0.9342998266220093, 'elapsed_time': 0.02166604995727539}, orig: 1
# {'label': 1, 'confidence': 0.9858518838882446, 'elapsed_time': 0.017015695571899414}, orig: 0
# {'label': 0, 'confidence': 0.999994158744812, 'elapsed_time': 0.017462730407714844}, orig: 0
# {'label': 1, 'confidence': 0.8634677529335022, 'elapsed_time': 0.021683931350708008}, orig: 1
# {'label': 1, 'confidence': 0.9332205057144165, 'elapsed_time': 0.024605274200439453}, orig: 0
# {'label': 1, 'confidence': 0.9981045722961426, 'elapsed_time': 0.02583026885986328}, orig: 1
# {'label': 1, 'confidence': 0.9870467185974121, 'elapsed_time': 0.018550634384155273}, orig: 1
# {'label': 1, 'confidence': 0.9984771609306335, 'elapsed_time': 0.02203512191772461}, orig: 1
# {'label': 1, 'confidence': 0.7838062644004822, 'elapsed_time': 0.022066593170166016}, orig: 0
# {'label': 0, 'confidence': 0.9999791383743286, 'elapsed_time': 0.03113079071044922}, orig: 0
# {'label': 0, 'confidence': 1.0, 'elapsed_time': 0.016877174377441406}, orig: 0
# {'label': 1, 'confidence': 0.9892171621322632, 'elapsed_time': 0.02207636833190918}, orig: 1
# {'label': 1, 'confidence': 0.9998648166656494, 'elapsed_time': 0.022339582443237305}, orig: 1
# {'label': 1, 'confidence': 0.9999990463256836, 'elapsed_time': 0.03168034553527832}, orig: 1
# {'label': 0, 'confidence': 0.9634382724761963, 'elapsed_time': 0.024952411651611328}, orig: 0
# {'label': 1, 'confidence': 0.8334028720855713, 'elapsed_time': 0.021772384643554688}, orig: 0
# {'label': 1, 'confidence': 0.9989345669746399, 'elapsed_time': 0.022758007049560547}, orig: 1
# {'label': 1, 'confidence': 0.9976449608802795, 'elapsed_time': 0.02454400062561035}, orig: 1
# {'label': 0, 'confidence': 0.986834704875946, 'elapsed_time': 0.01757335662841797}, orig: 0
# {'label': 1, 'confidence': 0.9728968739509583, 'elapsed_time': 0.01758122444152832}, orig: 1
# {'label': 0, 'confidence': 0.9992820620536804, 'elapsed_time': 0.025607824325561523}, orig: 0
# {'label': 0, 'confidence': 0.9999995231628418, 'elapsed_time': 0.025397539138793945}, orig: 0
# {'label': 1, 'confidence': 0.9708915948867798, 'elapsed_time': 0.03158378601074219}, orig: 0
# {'label': 0, 'confidence': 0.9812036156654358, 'elapsed_time': 0.021477937698364258}, orig: 0
# {'label': 1, 'confidence': 0.5147914886474609, 'elapsed_time': 0.02216196060180664}, orig: 0
# {'label': 1, 'confidence': 0.9870744943618774, 'elapsed_time': 0.02417922019958496}, orig: 1
# {'label': 1, 'confidence': 0.8732839822769165, 'elapsed_time': 0.024417877197265625}, orig: 1
# {'label': 1, 'confidence': 0.9999862909317017, 'elapsed_time': 0.017783164978027344}, orig: 1
# {'label': 1, 'confidence': 0.9960607886314392, 'elapsed_time': 0.02086353302001953}, orig: 1
# {'label': 0, 'confidence': 0.8814038634300232, 'elapsed_time': 0.017661094665527344}, orig: 1
# {'label': 1, 'confidence': 0.9987537860870361, 'elapsed_time': 0.022142887115478516}, orig: 1
# {'label': 1, 'confidence': 0.7651633024215698, 'elapsed_time': 0.02241826057434082}, orig: 1
# {'label': 0, 'confidence': 0.8769564628601074, 'elapsed_time': 0.02510833740234375}, orig: 0
# {'label': 1, 'confidence': 0.9195670485496521, 'elapsed_time': 0.01806354522705078}, orig: 1
# {'label': 0, 'confidence': 0.816351592540741, 'elapsed_time': 0.016985416412353516}, orig: 0
# {'label': 1, 'confidence': 0.9992780089378357, 'elapsed_time': 0.01808023452758789}, orig: 1
# {'label': 1, 'confidence': 0.999954104423523, 'elapsed_time': 0.022547245025634766}, orig: 1
# {'label': 1, 'confidence': 0.9980781078338623, 'elapsed_time': 0.01839423179626465}, orig: 1
# {'label': 1, 'confidence': 0.9999732971191406, 'elapsed_time': 0.022056102752685547}, orig: 1
# {'label': 1, 'confidence': 0.9730179905891418, 'elapsed_time': 0.022140026092529297}, orig: 1
# {'label': 0, 'confidence': 0.9999769926071167, 'elapsed_time': 0.017975568771362305}, orig: 0
# {'label': 0, 'confidence': 0.9790191650390625, 'elapsed_time': 0.018471240997314453}, orig: 0
# {'label': 1, 'confidence': 0.999394416809082, 'elapsed_time': 0.017946481704711914}, orig: 1
# {'label': 1, 'confidence': 0.9966495633125305, 'elapsed_time': 0.016969919204711914}, orig: 1
# {'label': 1, 'confidence': 0.9862263798713684, 'elapsed_time': 0.023359060287475586}, orig: 1
# {'label': 1, 'confidence': 0.9458896517753601, 'elapsed_time': 0.024545907974243164}, orig: 1
# {'label': 0, 'confidence': 0.9991363883018494, 'elapsed_time': 0.017416000366210938}, orig: 0
# {'label': 1, 'confidence': 0.9927240014076233, 'elapsed_time': 0.018954992294311523}, orig: 1
# {'label': 0, 'confidence': 0.936321496963501, 'elapsed_time': 0.027421236038208008}, orig: 0
# {'label': 0, 'confidence': 0.9838152527809143, 'elapsed_time': 0.025189638137817383}, orig: 0
# {'label': 1, 'confidence': 0.9402620196342468, 'elapsed_time': 0.02244400978088379}, orig: 0
# {'label': 0, 'confidence': 0.9999980926513672, 'elapsed_time': 0.01713085174560547}, orig: 0
# {'label': 0, 'confidence': 0.958130419254303, 'elapsed_time': 0.01763606071472168}, orig: 0
# {'label': 1, 'confidence': 0.871355414390564, 'elapsed_time': 0.018837451934814453}, orig: 1
# {'label': 1, 'confidence': 0.9997633099555969, 'elapsed_time': 0.01771259307861328}, orig: 1
# {'label': 1, 'confidence': 0.9993352293968201, 'elapsed_time': 0.02231121063232422}, orig: 1
# {'label': 1, 'confidence': 0.9850403070449829, 'elapsed_time': 0.018350839614868164}, orig: 1
# {'label': 1, 'confidence': 0.9918891787528992, 'elapsed_time': 0.017911911010742188}, orig: 1
# {'label': 1, 'confidence': 0.9869275689125061, 'elapsed_time': 0.021891355514526367}, orig: 1
# {'label': 1, 'confidence': 0.714474618434906, 'elapsed_time': 0.021255970001220703}, orig: 0
# {'label': 1, 'confidence': 0.9998908042907715, 'elapsed_time': 0.018386125564575195}, orig: 1
# {'label': 1, 'confidence': 0.9805046916007996, 'elapsed_time': 0.024675846099853516}, orig: 1
# {'label': 1, 'confidence': 0.9999393224716187, 'elapsed_time': 0.017346620559692383}, orig: 1
# {'label': 0, 'confidence': 0.8124919533729553, 'elapsed_time': 0.017899513244628906}, orig: 0
# {'label': 1, 'confidence': 0.9641488790512085, 'elapsed_time': 0.021311044692993164}, orig: 1
# {'label': 0, 'confidence': 0.9997466206550598, 'elapsed_time': 0.017195701599121094}, orig: 0
# {'label': 1, 'confidence': 0.9999744892120361, 'elapsed_time': 0.022266864776611328}, orig: 1
# {'label': 1, 'confidence': 0.9784165620803833, 'elapsed_time': 0.017891645431518555}, orig: 1
# {'label': 1, 'confidence': 0.8296223878860474, 'elapsed_time': 0.021970748901367188}, orig: 1
# {'label': 1, 'confidence': 0.9984501600265503, 'elapsed_time': 0.017405033111572266}, orig: 1
# {'label': 0, 'confidence': 0.8751111626625061, 'elapsed_time': 0.02422642707824707}, orig: 0
# {'label': 1, 'confidence': 0.9918031096458435, 'elapsed_time': 0.018172264099121094}, orig: 1
# {'label': 1, 'confidence': 0.9996115565299988, 'elapsed_time': 0.022084712982177734}, orig: 1
# {'label': 1, 'confidence': 0.9999994039535522, 'elapsed_time': 0.017885923385620117}, orig: 1
# {'label': 1, 'confidence': 0.9765461683273315, 'elapsed_time': 0.025334835052490234}, orig: 1
# {'label': 0, 'confidence': 0.9999995231628418, 'elapsed_time': 0.021889448165893555}, orig: 0
# {'label': 0, 'confidence': 0.9999980926513672, 'elapsed_time': 0.018752098083496094}, orig: 0
# {'label': 1, 'confidence': 0.8879197835922241, 'elapsed_time': 0.020154237747192383}, orig: 0
# {'label': 1, 'confidence': 0.992928683757782, 'elapsed_time': 0.022508859634399414}, orig: 1
# {'label': 0, 'confidence': 0.9999985694885254, 'elapsed_time': 0.02479410171508789}, orig: 0
# {'label': 0, 'confidence': 0.9396997690200806, 'elapsed_time': 0.018476247787475586}, orig: 0
# {'label': 1, 'confidence': 0.9135506749153137, 'elapsed_time': 0.018306255340576172}, orig: 1
# {'label': 1, 'confidence': 0.8220605254173279, 'elapsed_time': 0.0249330997467041}, orig: 1
# {'label': 1, 'confidence': 0.9998810291290283, 'elapsed_time': 0.018240690231323242}, orig: 1
# {'label': 1, 'confidence': 0.5273440480232239, 'elapsed_time': 0.018164873123168945}, orig: 1
# {'label': 0, 'confidence': 0.867328405380249, 'elapsed_time': 0.01745748519897461}, orig: 0
# {'label': 0, 'confidence': 0.9989964365959167, 'elapsed_time': 0.019145727157592773}, orig: 0
# {'label': 1, 'confidence': 0.9999994039535522, 'elapsed_time': 0.0222930908203125}, orig: 0
# {'label': 1, 'confidence': 0.9999672174453735, 'elapsed_time': 0.02425837516784668}, orig: 1
# {'label': 1, 'confidence': 0.9982805252075195, 'elapsed_time': 0.025053977966308594}, orig: 1
# {'label': 0, 'confidence': 0.999963641166687, 'elapsed_time': 0.020356178283691406}, orig: 0
# {'label': 1, 'confidence': 0.9984471201896667, 'elapsed_time': 0.02527928352355957}, orig: 1
# {'label': 1, 'confidence': 0.94405198097229, 'elapsed_time': 0.025408029556274414}, orig: 1
# {'label': 0, 'confidence': 0.9994041919708252, 'elapsed_time': 0.017632246017456055}, orig: 0
# {'label': 0, 'confidence': 0.9801613688468933, 'elapsed_time': 0.02271866798400879}, orig: 0
# {'label': 1, 'confidence': 0.5667914748191833, 'elapsed_time': 0.02260422706604004}, orig: 1
# {'label': 0, 'confidence': 0.9999357461929321, 'elapsed_time': 0.017751216888427734}, orig: 0
# {'label': 1, 'confidence': 0.9775894284248352, 'elapsed_time': 0.021823883056640625}, orig: 1
# {'label': 1, 'confidence': 0.999580442905426, 'elapsed_time': 0.018047332763671875}, orig: 1
# {'label': 0, 'confidence': 0.9625512361526489, 'elapsed_time': 0.017278671264648438}, orig: 1
# {'label': 0, 'confidence': 0.8742074370384216, 'elapsed_time': 0.01733231544494629}, orig: 1
# {'label': 0, 'confidence': 0.6291520595550537, 'elapsed_time': 0.02154254913330078}, orig: 1
# {'label': 1, 'confidence': 0.9163445234298706, 'elapsed_time': 0.02209949493408203}, orig: 1
# {'label': 0, 'confidence': 0.9999732971191406, 'elapsed_time': 0.01874828338623047}, orig: 0
# {'label': 0, 'confidence': 0.697239100933075, 'elapsed_time': 0.017491817474365234}, orig: 0
# {'label': 1, 'confidence': 0.9995373487472534, 'elapsed_time': 0.019475460052490234}, orig: 1
# {'label': 1, 'confidence': 0.9978201389312744, 'elapsed_time': 0.018366098403930664}, orig: 1
# {'label': 1, 'confidence': 0.9999741315841675, 'elapsed_time': 0.0218350887298584}, orig: 1
# {'label': 1, 'confidence': 0.9642122387886047, 'elapsed_time': 0.022312164306640625}, orig: 1
# {'label': 1, 'confidence': 0.9996008276939392, 'elapsed_time': 0.02263164520263672}, orig: 1
# {'label': 1, 'confidence': 0.994239091873169, 'elapsed_time': 0.01718592643737793}, orig: 1
# {'label': 1, 'confidence': 0.9831974506378174, 'elapsed_time': 0.017778873443603516}, orig: 1
# {'label': 1, 'confidence': 0.9999918937683105, 'elapsed_time': 0.024997949600219727}, orig: 1
# {'label': 0, 'confidence': 0.9961292743682861, 'elapsed_time': 0.01853156089782715}, orig: 0
# {'label': 0, 'confidence': 0.9981215596199036, 'elapsed_time': 0.018320083618164062}, orig: 0
# {'label': 1, 'confidence': 0.9999479055404663, 'elapsed_time': 0.01803731918334961}, orig: 1
# {'label': 0, 'confidence': 0.9334105253219604, 'elapsed_time': 0.022185564041137695}, orig: 0
# {'label': 0, 'confidence': 0.9997214674949646, 'elapsed_time': 0.022396087646484375}, orig: 0
# {'label': 1, 'confidence': 0.9745513796806335, 'elapsed_time': 0.02462148666381836}, orig: 0
# {'label': 0, 'confidence': 0.9937220215797424, 'elapsed_time': 0.017262697219848633}, orig: 0
# {'label': 1, 'confidence': 0.9960885047912598, 'elapsed_time': 0.017072200775146484}, orig: 1
# {'label': 0, 'confidence': 0.999823272228241, 'elapsed_time': 0.02259659767150879}, orig: 0
# {'label': 1, 'confidence': 0.9998787641525269, 'elapsed_time': 0.02454233169555664}, orig: 1
# {'label': 1, 'confidence': 0.7275501489639282, 'elapsed_time': 0.01769423484802246}, orig: 0
# {'label': 1, 'confidence': 0.9993176460266113, 'elapsed_time': 0.020536422729492188}, orig: 1
# {'label': 1, 'confidence': 0.7655158042907715, 'elapsed_time': 0.028814077377319336}, orig: 0
# {'label': 1, 'confidence': 0.5044973492622375, 'elapsed_time': 0.019382476806640625}, orig: 1
# {'label': 0, 'confidence': 0.9999998807907104, 'elapsed_time': 0.01721358299255371}, orig: 0
# {'label': 1, 'confidence': 0.8940288424491882, 'elapsed_time': 0.017395496368408203}, orig: 1
# {'label': 0, 'confidence': 0.6016013622283936, 'elapsed_time': 0.021546602249145508}, orig: 0
# {'label': 1, 'confidence': 0.9593047499656677, 'elapsed_time': 0.021987199783325195}, orig: 1
# {'label': 1, 'confidence': 0.9666778445243835, 'elapsed_time': 0.01761174201965332}, orig: 1
# {'label': 1, 'confidence': 0.9989363551139832, 'elapsed_time': 0.017841339111328125}, orig: 1
# {'label': 1, 'confidence': 0.8525994420051575, 'elapsed_time': 0.020960092544555664}, orig: 1
# {'label': 1, 'confidence': 0.9833074808120728, 'elapsed_time': 0.03160858154296875}, orig: 1
# {'label': 0, 'confidence': 0.9437058568000793, 'elapsed_time': 0.03161454200744629}, orig: 0
# {'label': 1, 'confidence': 0.9461022615432739, 'elapsed_time': 0.020478248596191406}, orig: 0
# {'label': 1, 'confidence': 0.9999171495437622, 'elapsed_time': 0.017576932907104492}, orig: 1
# {'label': 1, 'confidence': 0.9801521897315979, 'elapsed_time': 0.017244577407836914}, orig: 1
# {'label': 1, 'confidence': 0.9960607886314392, 'elapsed_time': 0.024509668350219727}, orig: 1
# {'label': 0, 'confidence': 0.993857204914093, 'elapsed_time': 0.02179694175720215}, orig: 0
# {'label': 1, 'confidence': 0.994852602481842, 'elapsed_time': 0.024984359741210938}, orig: 1
# {'label': 1, 'confidence': 0.9999961853027344, 'elapsed_time': 0.017896652221679688}, orig: 1
# {'label': 1, 'confidence': 0.999546468257904, 'elapsed_time': 0.02235722541809082}, orig: 1
# {'label': 0, 'confidence': 0.604171633720398, 'elapsed_time': 0.017295360565185547}, orig: 1
# {'label': 0, 'confidence': 0.9643955826759338, 'elapsed_time': 0.01757645606994629}, orig: 0
# {'label': 1, 'confidence': 0.5012322068214417, 'elapsed_time': 0.02213120460510254}, orig: 0
# {'label': 1, 'confidence': 0.9965332746505737, 'elapsed_time': 0.022161006927490234}, orig: 1
# {'label': 1, 'confidence': 0.9999980926513672, 'elapsed_time': 0.02623605728149414}, orig: 1
# {'label': 0, 'confidence': 0.999903678894043, 'elapsed_time': 0.01848149299621582}, orig: 0
# {'label': 1, 'confidence': 0.9984055161476135, 'elapsed_time': 0.01790475845336914}, orig: 1
# {'label': 1, 'confidence': 0.999710738658905, 'elapsed_time': 0.017433643341064453}, orig: 1
# {'label': 1, 'confidence': 0.9972372055053711, 'elapsed_time': 0.021294355392456055}, orig: 1
# {'label': 1, 'confidence': 0.9950609803199768, 'elapsed_time': 0.02250218391418457}, orig: 1
# {'label': 0, 'confidence': 0.9999439716339111, 'elapsed_time': 0.02226114273071289}, orig: 0
# {'label': 1, 'confidence': 0.999718964099884, 'elapsed_time': 0.017490386962890625}, orig: 1
# {'label': 1, 'confidence': 0.6536669135093689, 'elapsed_time': 0.02570796012878418}, orig: 1
# {'label': 1, 'confidence': 0.6090734601020813, 'elapsed_time': 0.01837778091430664}, orig: 1
# {'label': 0, 'confidence': 0.7683382630348206, 'elapsed_time': 0.03137350082397461}, orig: 1
# {'label': 0, 'confidence': 0.9999897480010986, 'elapsed_time': 0.03155660629272461}, orig: 0
# {'label': 1, 'confidence': 0.9998942613601685, 'elapsed_time': 0.01813793182373047}, orig: 1
# {'label': 0, 'confidence': 0.5738729238510132, 'elapsed_time': 0.02315807342529297}, orig: 0
# {'label': 1, 'confidence': 0.9973894953727722, 'elapsed_time': 0.025746583938598633}, orig: 1
# {'label': 1, 'confidence': 0.9131306409835815, 'elapsed_time': 0.02183365821838379}, orig: 1
# {'label': 1, 'confidence': 0.9989975094795227, 'elapsed_time': 0.02204155921936035}, orig: 1
# {'label': 0, 'confidence': 0.9934459328651428, 'elapsed_time': 0.018227100372314453}, orig: 0
# {'label': 1, 'confidence': 0.9943935871124268, 'elapsed_time': 0.029125213623046875}, orig: 1
# {'label': 1, 'confidence': 0.9999967813491821, 'elapsed_time': 0.01867198944091797}, orig: 1
# {'label': 1, 'confidence': 0.9999984502792358, 'elapsed_time': 0.024627208709716797}, orig: 1
# {'label': 1, 'confidence': 1.0, 'elapsed_time': 0.024045944213867188}, orig: 1
# {'label': 1, 'confidence': 0.8881404399871826, 'elapsed_time': 0.02175760269165039}, orig: 0
# {'label': 0, 'confidence': 0.9999983310699463, 'elapsed_time': 0.01781487464904785}, orig: 0
# {'label': 1, 'confidence': 0.9964852333068848, 'elapsed_time': 0.021999835968017578}, orig: 1
# {'label': 1, 'confidence': 0.939290463924408, 'elapsed_time': 0.022115707397460938}, orig: 1
# {'label': 1, 'confidence': 0.9939897060394287, 'elapsed_time': 0.030078887939453125}, orig: 1
# {'label': 1, 'confidence': 0.9999896287918091, 'elapsed_time': 0.017361879348754883}, orig: 1
# {'label': 1, 'confidence': 0.9908287525177002, 'elapsed_time': 0.017936229705810547}, orig: 1
# {'label': 1, 'confidence': 0.9858801960945129, 'elapsed_time': 0.021485567092895508}, orig: 1

# %%
from sklearn.metrics import accuracy_score

none_count = 0
res2 = []
test2 = []

for r, t in zip(res, test_y):
    if r is not None:
        res2.append(r['label'])
        test2.append(t)
    else:
        none_count += 1
        
print(none_count)
accuracy_score(test2, res2)
# Out:
# 0
# 0.8598726114649682

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_y)
# Out:
# LabelEncoder()

# %%
import numpy as np

def dummy_val(r):
    return r['label'] if r is not None else -1

test2_arr = np.array(test_y)
res2_arr = np.array([dummy_val(r) for r in res])

filter_inds = np.not_equal(test2_arr, res2_arr)
incorrectly_clf_X = test['text'][filter_inds]
incorrectly_clf_y = test_y[filter_inds]

# %%
for i, text in enumerate(incorrectly_clf_X):
    print(f"Class: {incorrectly_clf_y.iloc[i]}, index: {incorrectly_clf_X.index[i]}")
    print(text)
    print()
# Out:
# Class: 0, index: 977
# answer gained weight need new jeans exercise know
#
# Class: 0, index: 335
# necessary take break social media toss fashion magazines
#
# Class: 0, index: 779
# um know many calories slice never ready ashton kutcher appear tell middle prank
#
# Class: 0, index: 397
# fall misguided belief handle binge eating anorexia bulimia
#
# Class: 0, index: 951
# canada though sorry resources mentioned however available worldwide
#
# Class: 0, index: 793
# remember sitting around kitchen table trying explain dissatisfied
#
# Class: 0, index: 345
# outdoor activities especially good boosting sense well
#
# Class: 1, index: 3007
# everyone struggle different
#
# Class: 1, index: 1560
# patients also trained importance better eating patterns
#
# Class: 0, index: 716
# obesity caused bed lead heart disease diabetes hypertension related issues
#
# Class: 1, index: 1739
# mind
#
# Class: 1, index: 2422
# earliest
#
# Class: 1, index: 1605
# understand want lose weight anorexia
#
# Class: 0, index: 179
# say fine
#
# Class: 0, index: 16
# however true
#
# Class: 0, index: 1110
# friends want things helps keep head also forces go meals
#
# Class: 1, index: 1261
# get perception weigh
#
# Class: 1, index: 2305
# food pain
#
# Class: 1, index: 1454
# try eating alone encouraged sometimes eat alone keep lifestyle choice secret loved ones long possible
#
# Class: 0, index: 766
# feel uncomfortable eating sweets
#
# Class: 1, index: 3107
# ended going another friends house party edibles super fun next day old friend text ed bunch nasty stuff really shook got
#
# Class: 0, index: 988
# im getting cream marshmallows maybe ill hide corner drink cry little fuck
#
# Class: 0, index: 863
# family perfect
#
# Class: 0, index: 329
# tips improve body image dress others
#
# Class: 0, index: 973
# bit context
#
# Class: 1, index: 2134
# anorexics often face depression well lead suicide long run
#
# Class: 1, index: 2613
# sudden anorexia makes realize part anything christmas approaches cant take part
#
# Class: 0, index: 1174
# started reading everything could get hands
#
# Class: 0, index: 331
# pick clothes express personality make feel comfortable confident
#
# Class: 0, index: 270
# may include regular weigh blood tests health screenings
#
# Class: 0, index: 1210
# every time would happen spend lot time asking
#
# Class: 0, index: 188
# remember come achieved far come adventure
#
# Class: 0, index: 353
# avoid pro pro mia websites
#
# Class: 1, index: 2898
# encourage person travel road eating disorders
#
# Class: 1, index: 3108
# besides actually well posh mark pop pin lately along mer cari de pop v ted really awesome going sourcing saturday favorite part
#
# Class: 1, index: 1347
# result able appreciate loveliness nature flowers breeze face clouds trees sky moon stars
#
# Class: 0, index: 1225
# using site please read privacy policy terms use
#
# Class: 0, index: 1
# long battle anorexia
#
# Class: 0, index: 334
# people exaggerate positive aspects lives facebook insta gram like brushing flaws doubts disappointments experience
#
# Class: 0, index: 256
# nothing important well
#
# Class: 1, index: 2951
# food ultimate enemy
#
# Class: 0, index: 834
# people want talk help regardless label carrying around
#
# Class: 1, index: 2563
# ready excuses eating less salad excuse food poisoning every time becomes fishy
#
# Class: 0, index: 311
# think things like
